# %%
import pandas as pd

# %%
df = pd.read_csv ("./data/videos.csv")

# %%
df
# Out:
#                                                  Title  \
# 0                      SLIME CASERO | ¿Por qué sucede?
# 1        PASTA DE DIENTES DE ELEFANTE | ¿Por qué pasa?
# 2                OBTENIENDO COBRE A PARTIR DE ALUMINIO
# 3         HACIENDO CLOROFORMO | Reacción del haloformo
# 4                   SUMA DE MATRICES Y SUS PROPIEDADES
# ..                                                 ...
# 664  IONES: CATIONES Y ANIONES ¿QUÉ SON?| Química B...
# 665                ESTRUCTURA ATÓMICA | Química Básica
# 666                  MODELOS ATOMICOS | Química Básica
# 667  DIFERENCIA ENTRE ÁTOMOS Y MOLÉCULAS | Química ...
# 668  DIFERENCIA ENTRE ÁTOMOS Y MOLÉCULAS | Química ...
#
#                                             Link           ID  \
# 0    https://www.youtube.com/watch?v=ILDx1z4gyxQ  ILDx1z4gyxQ
# 1    https://www.youtube.com/watch?v=YHCS365Vcqo  YHCS365Vcqo
# 2    https://www.youtube.com/watch?v=UA9qac8nvM0  UA9qac8nvM0
# ...

# %%
import requests
url = "https://ve65.aadika.xyz/download/DbnKVqmJrkQ/mp3/128/1673122610/425a2abf7604b11388c299732cb6862ac20f4a60c507f452402e9798f51578b9/1?f=SnapSave.io"
r = requests.get(url)
with open('./song.mp3', 'wb') as f:
    f.write(r.content)
    
# Retrieve HTTP meta-data
print(r.status_code)
print(r.headers['content-type'])
print(r.encoding)
# Out:
# 200
# audio/mpeg3
# None

# %%
df["Corrected Title"]=df["Title"].str.extract(r"([\w{1,}\s:]+)")
df
# Out:
#                                                  Title  \
# 0                      SLIME CASERO | ¿Por qué sucede?
# 1        PASTA DE DIENTES DE ELEFANTE | ¿Por qué pasa?
# 2                OBTENIENDO COBRE A PARTIR DE ALUMINIO
# 3         HACIENDO CLOROFORMO | Reacción del haloformo
# 4                   SUMA DE MATRICES Y SUS PROPIEDADES
# ..                                                 ...
# 664  IONES: CATIONES Y ANIONES ¿QUÉ SON?| Química B...
# 665                ESTRUCTURA ATÓMICA | Química Básica
# 666                  MODELOS ATOMICOS | Química Básica
# 667  DIFERENCIA ENTRE ÁTOMOS Y MOLÉCULAS | Química ...
# 668  DIFERENCIA ENTRE ÁTOMOS Y MOLÉCULAS | Química ...
#
#                                             Link           ID  \
# 0    https://www.youtube.com/watch?v=ILDx1z4gyxQ  ILDx1z4gyxQ
# 1    https://www.youtube.com/watch?v=YHCS365Vcqo  YHCS365Vcqo
# 2    https://www.youtube.com/watch?v=UA9qac8nvM0  UA9qac8nvM0
# ...

# %%
df["Downl"]="ok"

# %%
df
# Out:
#                                                  Title  \
# 0                      SLIME CASERO | ¿Por qué sucede?
# 1        PASTA DE DIENTES DE ELEFANTE | ¿Por qué pasa?
# 2                OBTENIENDO COBRE A PARTIR DE ALUMINIO
# 3         HACIENDO CLOROFORMO | Reacción del haloformo
# 4                   SUMA DE MATRICES Y SUS PROPIEDADES
# ..                                                 ...
# 664  IONES: CATIONES Y ANIONES ¿QUÉ SON?| Química B...
# 665                ESTRUCTURA ATÓMICA | Química Básica
# 666                  MODELOS ATOMICOS | Química Básica
# 667  DIFERENCIA ENTRE ÁTOMOS Y MOLÉCULAS | Química ...
# 668  DIFERENCIA ENTRE ÁTOMOS Y MOLÉCULAS | Química ...
#
#                                             Link           ID  \
# 0    https://www.youtube.com/watch?v=ILDx1z4gyxQ  ILDx1z4gyxQ
# 1    https://www.youtube.com/watch?v=YHCS365Vcqo  YHCS365Vcqo
# 2    https://www.youtube.com/watch?v=UA9qac8nvM0  UA9qac8nvM0
# ...

# %%
new={"msg":"success"}

if new["msg"] == "success":
    print("ok")
# Out:
# ok

# %%
new["msg"]
# Out:
# 'sucess'

# %%
for i in df["Link"]:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv ("./data/videos.csv")

# %%
df
# Out:
#                                                  Title  \
# 0    APRENDER RÁPIDO LA TABLA PERIÓDICA | Tips y Tr...
# 1                 OBTENIENDO ACEITE ESENCIAL DE ROMERO
# 2                        QUÉ ES EL pH | Química Básica
# 3    ESTRUCTURA DE LEWIS Y REGLA DEL OCTETO | Quími...
# 4                                    QUE ES UN ISOTOPO
# ..                                                 ...
# 664  CARBONIZAR PAN | Quimicefa en vídeo | Experime...
# 665  COBRE + ÁCIDO | Quimicefa en vídeo | Experimen...
# 666  H2O DE LA COMBUSTIÓN | Quimicefa en vídeo | Ex...
# 667  ASFIXIAR UNA LLAMA | Quimicefa en vídeo | Expe...
# 668  ASFIXIAR UNA LLAMA | Quimicefa en vídeo | Expe...
#
#                                             Link           ID
# 0    https://www.youtube.com/watch?v=WnSS5mu28qs  WnSS5mu28qs
# 1    https://www.youtube.com/watch?v=TZ4nFjgGNac  TZ4nFjgGNac
# 2    https://www.youtube.com/watch?v=vIf54jqQmKU  vIf54jqQmKU
# ...
